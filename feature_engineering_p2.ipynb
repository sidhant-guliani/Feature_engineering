# %% [markdown]
# In this section we are going to deal with automated feature engineering using Featuretools. It is an opensource python library
#
# The concept of Deep Feature Synthesis is to use basic building blocks known as feature primitives (like the transformations and aggregations done above) that can be stacked on top of each other to form new features. The depth of a "deep feature" is equal to the number of stacked primitives.
#
#     step 1: defining entities (tables) in an EntitySet
#     step 2: definiing the relationship between the entities
#     step 3: defining premitive features
#
# we can see how useful featuretools is: it performed the same operations we did manually but also many more in addition. Examining the names of the features in the dataframe brings us to the final piece of the puzzle: deep features.
#
# Explaining what these features are:
#
#     MEAN(loans.loan_amount): If client A has 1000 loans then this feature will represent the mean of all the loans

# %%
#! pip install featuretools

# %%
import pandas as pd
import numpy as np

import featuretools as ft
import warnings 

pd.options.display.max_colwidth = 200

# %%
clients = pd.read_csv('clients.csv', parse_dates = ['joined'])
loans = pd.read_csv('loans.csv', parse_dates = ['loan_start', 'loan_end'])
payments = pd.read_csv('payments.csv', parse_dates = ['payment_date'])

# %%
print(clients.columns)
print(loans.columns)
print(payments.columns)
# Out:
# Index(['client_id', 'joined', 'income', 'credit_score'], dtype='object')
# Index(['client_id', 'loan_type', 'loan_amount', 'repaid', 'loan_id',
#        'loan_start', 'loan_end', 'rate'],
#       dtype='object')
# Index(['loan_id', 'payment_amount', 'payment_date', 'missed'], dtype='object')

# %%
stats_table = loans.groupby('client_id')['loan_amount'].agg(['mean', 'max', 'min'])
stats_table.columns = ['mean_loan_amount', 'max_loan_amount', 'min_loan_amount']

# %%
stats_table.head()
# Out:
#            mean_loan_amount  max_loan_amount  min_loan_amount
# client_id
# 2003            5010.666667            10314             2267
# 2004           11882.000000            12651            10464
# 2011           12006.000000            13339             9837
# 2031            7311.300000            13975              772
# 2041            7054.142857            14024             1049

# %%
print(len(clients['client_id'].unique()))
print(len(stats_table))
print(len(loans['client_id'].unique()))
# Out:
# 241
# 232
# 232

# %%
clients_manual = clients.merge(stats_table, left_on = 'client_id', right_index=True, how = 'left')
clients_manual.head(10)
# Out:
#    client_id     joined  income  credit_score  mean_loan_amount  \
# 0       2697 2013-02-14   45903           507       7016.600000
# 1       4647 2005-06-23   47037           628       7374.700000
# 2       3230 2002-05-06   35246           555       7531.352941
# 3       3214 2006-08-26   42311           669       6077.105263
# 4       2265 2000-08-28   40387           679       7562.055556
# 5       2483 2013-05-19   49188           511       5911.052632
# 6       3092 2005-05-15   48432           766       7485.947368
# 7       3441 2001-06-10   45021           746       8079.150000
# 8       2489 2002-04-17   42915           655       7740.000000
# 9       2909 2011-07-03   49407           503       7828.666667
#
#    max_loan_amount  min_loan_amount
# 0          14927.0           1262.0
# 1          13708.0            807.0
# 2          14406.0            705.0
# 3          13298.0            852.0
# 4          14804.0            587.0
# 5          13875.0            934.0
# 6          14769.0            726.0
# 7          13985.0            630.0
# 8          14306.0           1231.0
# 9          14574.0           1428.0

# %%
null_columns = clients_manual.columns[clients_manual.isnull().any()]
clients_manual[null_columns].isnull().sum()
# Out:
# mean_loan_amount    9
# max_loan_amount     9
# min_loan_amount     9
# dtype: int64

# %% [markdown]
# creating an entity which is just a table.
#
#         1. index: Unique identifier
#         2. time_index:
#         3. make_index: True/False
# If the data also has a uniquely identifying time index, we can pass that in as the time_index parameter.

# %%
es = ft.EntitySet(id = 'clients')
es = es.entity_from_dataframe(entity_id = 'clients', dataframe = clients, 
                              index = 'client_id', time_index = 'joined')

# %%
payments.columns
# Out:
# Index(['loan_id', 'payment_amount', 'payment_date', 'missed'], dtype='object')

# %%
es = es.entity_from_dataframe(entity_id = 'loans', 
                              dataframe = loans, 
                              index = 'loan_id', 
                              time_index = 'loan_start')

# %%
es = es.entity_from_dataframe(entity_id = 'payments', 
                              dataframe = payments,
                              make_index = True,
                              index = 'payment_id',
                              time_index = 'payment_date')

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 241, Columns: 4]
#     loans [Rows: 1811, Columns: 8]
#     payments [Rows: 33708, Columns: 5]
#   Relationships:
#     No relationships

# %%
es['loans']
# Out:
# Entity: loans
#   Variables:
#     loan_id (dtype: index)
#     client_id (dtype: numeric)
#     loan_type (dtype: categorical)
#     loan_amount (dtype: numeric)
#     repaid (dtype: numeric)
#     loan_start (dtype: datetime_time_index)
#     loan_end (dtype: datetime)
#     rate (dtype: numeric)
#   Shape:
#     (Rows: 1811, Columns: 8)

# %%
es['clients']
# Out:
# Entity: clients
#   Variables:
#     client_id (dtype: index)
#     joined (dtype: datetime_time_index)
#     income (dtype: numeric)
#     credit_score (dtype: numeric)
#   Shape:
#     (Rows: 241, Columns: 4)

# %%
# in thsi step we are creating the relationship between client and loans
client_previous = ft.Relationship(es['clients']['client_id'],
                                    es['loans']['client_id'])

print(client_previous)
# Out:
# <Relationship: loans.client_id -> clients.client_id>

# %%
# Add the relationship to the entity set
es = es.add_relationship(client_previous)

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 241, Columns: 4]
#     loans [Rows: 1811, Columns: 8]
#     payments [Rows: 33708, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id

# %%
payments_relation = ft.Relationship(es['loans']['loan_id'],
                             es['payments']['loan_id'])
es = es.add_relationship(payments_relation)
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 241, Columns: 4]
#     loans [Rows: 1811, Columns: 8]
#     payments [Rows: 33708, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id
#     payments.loan_id -> loans.loan_id

# %% [markdown]
#  ## Premitive Features
# There are total of 78 premitive features, but two categories: aggregate and transform
#
#
# Aggregation:  function that groups together child datapoints for each parent and then calculates a statistic such as mean, min, max, or standard deviation
#
#  Transformation:  an operation applied to one or more columns in a single table. An example would be extracting the day from dates, or finding the difference between two columns in one table.

# %%
prim = ft.list_primitives()

# %%
prim
# Out:
#                      name         type  dask_compatible  \
# 0              num_unique  aggregation             True
# 1                    last  aggregation            False
# 2           n_most_common  aggregation            False
# 3                 entropy  aggregation            False
# 4                   count  aggregation             True
# ..                    ...          ...              ...
# 74                    not    transform             True
# 75             is_weekend    transform             True
# 76  divide_numeric_scalar    transform             True
# 77           equal_scalar    transform             True
# 78                    age    transform            False
#
#                                                          description
# 0   Determines the number of distinct values, ignoring `NaN` values.
# 1                               Determines the last value in a list.
# 2                           Determines the `n` most common elements.
# 3                  Calculates the entropy for a categorical variable
# 4            Determines the total number of values, excluding `NaN`.
# ..                                                               ...
# 74                                          Negates a boolean value.
# 75                          Determines if a date falls on a weekend.
# 76                      Divide each element in the list by a scalar.
# 77       Determines if values in a list are equal to a given scalar.
# 78    Calculates the age in years as a floating point number given a
#
# [79 rows x 4 columns]

# %%
prim[prim['type'] == 'aggregation'].head(10)
# Out:
#             name         type  dask_compatible  \
# 0     num_unique  aggregation             True
# 1           last  aggregation            False
# 2  n_most_common  aggregation            False
# 3        entropy  aggregation            False
# 4          count  aggregation             True
# 5           mode  aggregation            False
# 6          first  aggregation            False
# 7            min  aggregation             True
# 8            all  aggregation             True
# 9            sum  aggregation             True
#
#                                                         description
# 0  Determines the number of distinct values, ignoring `NaN` values.
# 1                              Determines the last value in a list.
# 2                          Determines the `n` most common elements.
# 3                 Calculates the entropy for a categorical variable
# 4           Determines the total number of values, excluding `NaN`.
# 5                      Determines the most commonly repeated value.
# 6                             Determines the first value in a list.
# 7             Calculates the smallest value, ignoring `NaN` values.
# 8                    Calculates if all values are 'True' in a list.
# 9                    Calculates the total addition, ignoring `NaN`.

# %%
prim[prim['type'] == 'transform'].head(10)
# Out:
#                      name       type  dask_compatible  \
# 22                   diff  transform            False
# 23                cum_max  transform            False
# 24       less_than_scalar  transform             True
# 25                     or  transform             True
# 26                   isin  transform             True
# 27                    day  transform             True
# 28       multiply_boolean  transform             True
# 29  modulo_numeric_scalar  transform             True
# 30                  month  transform             True
# 31                weekday  transform             True
#
#                                                     description
# 22   Compute the difference between the value in a list and the
# 23                           Calculates the cumulative maximum.
# 24           Determines if values are less than a given scalar.
# 25                        Element-wise logical OR of two lists.
# 26    Determines whether a value is present in a provided list.
# 27             Determines the day of the month from a datetime.
# 28  Element-wise multiplication of two lists of boolean values.
# 29   Return the modulo of each element in the list by a scalar.
# 30                    Determines the month value of a datetime.
# 31              Determines the day of the week from a datetime.

# %%
prim_transformative_name = prim[prim['type'] == 'transform']['name'].values
print(prim_transformative_name)
# Out:
# ['diff' 'cum_max' 'less_than_scalar' 'or' 'isin' 'day' 'multiply_boolean'
#  'modulo_numeric_scalar' 'month' 'weekday' 'cum_count' 'less_than'
#  'second' 'absolute' 'and' 'multiply_numeric_scalar' 'latitude' 'week'
#  'modulo_numeric' 'scalar_subtract_numeric_feature'
#  'less_than_equal_to_scalar' 'percentile' 'cum_min' 'divide_by_feature'
#  'subtract_numeric' 'less_than_equal_to' 'negate' 'hour' 'greater_than'
#  'year' 'divide_numeric' 'greater_than_equal_to' 'add_numeric'
#  'num_characters' 'time_since_previous' 'not_equal_scalar' 'num_words'
#  'minute' 'cum_sum' 'greater_than_equal_to_scalar' 'add_numeric_scalar'
#  'longitude' 'cum_mean' 'modulo_by_feature' 'multiply_numeric' 'equal'
#  'haversine' 'is_null' 'time_since' 'not_equal' 'subtract_numeric_scalar'
#  'greater_than_scalar' 'not' 'is_weekend' 'divide_numeric_scalar'
#  'equal_scalar' 'age']

# %% [markdown]
# ### Making our own features
# Using primitives is surprisingly easy using the ft.dfs function (which stands for deep feature synthesis). In this function, we specify the entityset to use; the target_entity, which is the dataframe we want to make the features for (where the features end up); the agg_primitives which are the aggregation feature primitives; and the trans_primitives which are the transformation primitives to apply.

# %%
# Create new features using specified primitives
features, feature_names = ft.dfs(entityset = es, target_entity = 'clients', 
                                 agg_primitives = ['mean', 'max', 'percent_true', 'last'],
                                 trans_primitives = ['month', 'diff','divide_numeric','year'])
# Out:
# C:\Users\Sidhant\Anaconda3\lib\site-packages\featuretools\synthesis\dfs.py:313: UnusedPrimitiveWarning: Some specified primitives were not used during DFS:
#   agg_primitives: ['percent_true']
# This may be caused by a using a value of max_depth that is too small, not setting interesting values, or it may indicate no compatible variable types for the primitive were found in the data.
#   warnings.warn(warning_msg, UnusedPrimitiveWarning)

# %%
pd.DataFrame(features['MONTH(joined)'].head())
# Out:
#            MONTH(joined)
# client_id
# 2447                   1
# 2963                   2
# 3294                   3
# 3895                   3
# 3469                   4

# %%
features.head()
# Out:
#            income  credit_score  MEAN(loans.loan_amount)  MEAN(loans.rate)  \
# client_id
# 2447        41501           546             11291.666667          5.483333
# 2963        47705           735              8586.000000          2.782000
# 3294        38544           769             12812.500000          3.500000
# 3895        39890           677              5542.285714          3.731429
# 3469        46552           607              8128.777778          4.211111
#
#            MEAN(loans.repaid)  MAX(loans.loan_amount)  MAX(loans.rate)  \
# client_id
# 2447                 0.666667                 14986.0            10.16
# 2963                 0.800000                 14759.0             7.16
# 3294                 0.500000                 13768.0             3.56
# 3895                 0.571429                 11475.0             5.17
# 3469                 0.222222                 14373.0             7.65
#
#            MAX(loans.repaid)  LAST(loans.loan_amount)  LAST(loans.loan_id)  \
# client_id
# 2447                     1.0                  10116.0              10285.0
# 2963                     1.0                  13700.0              11110.0
# 3294                     1.0                  13768.0              10890.0
# 3895                     1.0                  11475.0              11900.0
# 3469                     1.0                   2996.0              10397.0
#
#            ... income / MAX(payments.missed)  \
# client_id  ...
# 2447       ...                       41501.0
# 2963       ...                       47705.0
# 3294       ...                       38544.0
# 3895       ...                       39890.0
# 3469       ...                       46552.0
#
#            income / MAX(payments.payment_amount)  \
# client_id
# 2447                                   15.036594
# 2963                                   19.013551
# 3294                                   14.275556
# 3895                                   16.669453
# 3469                                   16.328306
#
#            income / MEAN(loans.loan_amount)  income / MEAN(loans.rate)  \
# client_id
# 2447                               3.675365                7568.571429
# 2963                               5.556138               17147.735442
# 3294                               3.008312               11012.571429
# 3895                               7.197391               10690.275651
# 3469                               5.726814               11054.564644
#
#            income / MEAN(loans.repaid)  income / MEAN(payments.missed)  \
# client_id
# 2447                          62251.50                    69168.333333
# 2963                          59631.25                    98301.212121
# 3294                          77088.00                   100214.400000
# 3895                          69807.50                    68900.909091
# 3469                         209484.00                    83452.975610
#
#            income / MEAN(payments.payment_amount)  YEAR(LAST(loans.loan_end))  \
# client_id
# 2447                                    32.409635                      2016.0
# 2963                                    46.065606                      2016.0
# 3294                                    19.222465                      2012.0
# 3895                                    40.911716                      2009.0
# 3469                                    39.472238                      2015.0
#
#            YEAR(LAST(loans.loan_start))  YEAR(LAST(payments.payment_date))
# client_id
# 2447                             2014.0                             2015.0
# 2963                             2014.0                             2015.0
# 3294                             2010.0                             2010.0
# 3895                             2008.0                             2011.0
# 3469                             2013.0                             2014.0
#
# [5 rows x 443 columns]

# %%
feature_names
# Out:
# [<Feature: income>,
#  <Feature: credit_score>,
#  <Feature: MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate)>,
#  <Feature: MEAN(loans.repaid)>,
#  <Feature: MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.rate)>,
#  <Feature: MAX(loans.repaid)>,
#  <Feature: LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_id)>,
#  <Feature: LAST(loans.loan_type)>,
#  <Feature: LAST(loans.rate)>,
#  <Feature: LAST(loans.repaid)>,
#  <Feature: MEAN(payments.missed)>,
#  <Feature: MEAN(payments.payment_amount)>,
#  <Feature: MAX(payments.missed)>,
#  <Feature: MAX(payments.payment_amount)>,
#  <Feature: LAST(payments.missed)>,
#  <Feature: LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_id)>,
#  <Feature: MONTH(joined)>,
#  <Feature: DIFF(credit_score)>,
#  <Feature: DIFF(income)>,
#  <Feature: credit_score / income>,
#  <Feature: income / credit_score>,
#  <Feature: YEAR(joined)>,
#  <Feature: MEAN(loans.DIFF(loan_amount))>,
#  <Feature: MEAN(loans.DIFF(rate))>,
#  <Feature: MEAN(loans.DIFF(repaid))>,
#  <Feature: MEAN(loans.LAST(payments.missed))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.missed))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEAN(payments.missed))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount / rate)>,
#  <Feature: MEAN(loans.loan_amount / repaid)>,
#  <Feature: MEAN(loans.rate / loan_amount)>,
#  <Feature: MEAN(loans.rate / repaid)>,
#  <Feature: MEAN(loans.repaid / loan_amount)>,
#  <Feature: MEAN(loans.repaid / rate)>,
#  <Feature: MAX(loans.DIFF(loan_amount))>,
#  <Feature: MAX(loans.DIFF(rate))>,
#  <Feature: MAX(loans.DIFF(repaid))>,
#  <Feature: MAX(loans.LAST(payments.missed))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.missed))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.loan_amount / repaid)>,
#  <Feature: MAX(loans.rate / loan_amount)>,
#  <Feature: MAX(loans.rate / repaid)>,
#  <Feature: MAX(loans.repaid / loan_amount)>,
#  <Feature: MAX(loans.repaid / rate)>,
#  <Feature: LAST(loans.DIFF(loan_amount))>,
#  <Feature: LAST(loans.DIFF(rate))>,
#  <Feature: LAST(loans.DIFF(repaid))>,
#  <Feature: LAST(loans.MAX(payments.missed))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.missed))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MONTH(loan_end))>,
#  <Feature: LAST(loans.MONTH(loan_start))>,
#  <Feature: LAST(loans.YEAR(loan_end))>,
#  <Feature: LAST(loans.YEAR(loan_start))>,
#  <Feature: LAST(loans.loan_amount / rate)>,
#  <Feature: LAST(loans.loan_amount / repaid)>,
#  <Feature: LAST(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.rate / repaid)>,
#  <Feature: LAST(loans.repaid / loan_amount)>,
#  <Feature: LAST(loans.repaid / rate)>,
#  <Feature: MEAN(payments.loans.loan_amount)>,
#  <Feature: MEAN(payments.loans.rate)>,
#  <Feature: MEAN(payments.loans.repaid)>,
#  <Feature: MAX(payments.loans.loan_amount)>,
#  <Feature: MAX(payments.loans.rate)>,
#  <Feature: MAX(payments.loans.repaid)>,
#  <Feature: LAST(payments.loans.client_id)>,
#  <Feature: LAST(payments.loans.loan_amount)>,
#  <Feature: LAST(payments.loans.loan_type)>,
#  <Feature: LAST(payments.loans.rate)>,
#  <Feature: LAST(payments.loans.repaid)>,
#  <Feature: MONTH(LAST(loans.loan_end))>,
#  <Feature: MONTH(LAST(loans.loan_start))>,
#  <Feature: MONTH(LAST(payments.payment_date))>,
#  <Feature: DIFF(LAST(loans.loan_amount))>,
#  <Feature: DIFF(LAST(loans.rate))>,
#  <Feature: DIFF(LAST(loans.repaid))>,
#  <Feature: DIFF(LAST(payments.missed))>,
#  <Feature: DIFF(LAST(payments.payment_amount))>,
#  <Feature: DIFF(MAX(loans.loan_amount))>,
#  <Feature: DIFF(MAX(loans.rate))>,
#  <Feature: DIFF(MAX(loans.repaid))>,
#  <Feature: DIFF(MAX(payments.missed))>,
#  <Feature: DIFF(MAX(payments.payment_amount))>,
#  <Feature: DIFF(MEAN(loans.loan_amount))>,
#  <Feature: DIFF(MEAN(loans.rate))>,
#  <Feature: DIFF(MEAN(loans.repaid))>,
#  <Feature: DIFF(MEAN(payments.missed))>,
#  <Feature: DIFF(MEAN(payments.payment_amount))>,
#  <Feature: DIFF(credit_score) / DIFF(income)>,
#  <Feature: DIFF(credit_score) / LAST(loans.loan_amount)>,
#  <Feature: DIFF(credit_score) / LAST(loans.rate)>,
#  <Feature: DIFF(credit_score) / LAST(loans.repaid)>,
#  <Feature: DIFF(credit_score) / LAST(payments.missed)>,
#  <Feature: DIFF(credit_score) / LAST(payments.payment_amount)>,
#  <Feature: DIFF(credit_score) / MAX(loans.loan_amount)>,
#  <Feature: DIFF(credit_score) / MAX(loans.rate)>,
#  <Feature: DIFF(credit_score) / MAX(loans.repaid)>,
#  <Feature: DIFF(credit_score) / MAX(payments.missed)>,
#  <Feature: DIFF(credit_score) / MAX(payments.payment_amount)>,
#  <Feature: DIFF(credit_score) / MEAN(loans.loan_amount)>,
#  <Feature: DIFF(credit_score) / MEAN(loans.rate)>,
#  <Feature: DIFF(credit_score) / MEAN(loans.repaid)>,
#  <Feature: DIFF(credit_score) / MEAN(payments.missed)>,
#  <Feature: DIFF(credit_score) / MEAN(payments.payment_amount)>,
#  <Feature: DIFF(credit_score) / credit_score>,
#  <Feature: DIFF(credit_score) / income>,
#  <Feature: DIFF(income) / DIFF(credit_score)>,
#  <Feature: DIFF(income) / LAST(loans.loan_amount)>,
#  <Feature: DIFF(income) / LAST(loans.rate)>,
#  <Feature: DIFF(income) / LAST(loans.repaid)>,
#  <Feature: DIFF(income) / LAST(payments.missed)>,
#  <Feature: DIFF(income) / LAST(payments.payment_amount)>,
#  <Feature: DIFF(income) / MAX(loans.loan_amount)>,
#  <Feature: DIFF(income) / MAX(loans.rate)>,
#  <Feature: DIFF(income) / MAX(loans.repaid)>,
#  <Feature: DIFF(income) / MAX(payments.missed)>,
#  <Feature: DIFF(income) / MAX(payments.payment_amount)>,
#  <Feature: DIFF(income) / MEAN(loans.loan_amount)>,
#  <Feature: DIFF(income) / MEAN(loans.rate)>,
#  <Feature: DIFF(income) / MEAN(loans.repaid)>,
#  <Feature: DIFF(income) / MEAN(payments.missed)>,
#  <Feature: DIFF(income) / MEAN(payments.payment_amount)>,
#  <Feature: DIFF(income) / credit_score>,
#  <Feature: DIFF(income) / income>,
#  <Feature: LAST(loans.loan_amount) / DIFF(credit_score)>,
#  <Feature: LAST(loans.loan_amount) / DIFF(income)>,
#  <Feature: LAST(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / LAST(loans.repaid)>,
#  <Feature: LAST(loans.loan_amount) / LAST(payments.missed)>,
#  <Feature: LAST(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / MAX(loans.repaid)>,
#  <Feature: LAST(loans.loan_amount) / MAX(payments.missed)>,
#  <Feature: LAST(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.repaid)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(payments.missed)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / credit_score>,
#  <Feature: LAST(loans.loan_amount) / income>,
#  <Feature: LAST(loans.rate) / DIFF(credit_score)>,
#  <Feature: LAST(loans.rate) / DIFF(income)>,
#  <Feature: LAST(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / LAST(loans.repaid)>,
#  <Feature: LAST(loans.rate) / LAST(payments.missed)>,
#  <Feature: LAST(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / MAX(loans.rate)>,
#  <Feature: LAST(loans.rate) / MAX(loans.repaid)>,
#  <Feature: LAST(loans.rate) / MAX(payments.missed)>,
#  <Feature: LAST(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / MEAN(loans.rate)>,
#  <Feature: LAST(loans.rate) / MEAN(loans.repaid)>,
#  <Feature: LAST(loans.rate) / MEAN(payments.missed)>,
#  <Feature: LAST(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / credit_score>,
#  <Feature: LAST(loans.rate) / income>,
#  <Feature: LAST(loans.repaid) / DIFF(credit_score)>,
#  <Feature: LAST(loans.repaid) / DIFF(income)>,
#  <Feature: LAST(loans.repaid) / LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.repaid) / LAST(loans.rate)>,
#  <Feature: LAST(loans.repaid) / LAST(payments.missed)>,
#  <Feature: LAST(loans.repaid) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.repaid) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.repaid) / MAX(loans.rate)>,
#  <Feature: LAST(loans.repaid) / MAX(loans.repaid)>,
#  <Feature: LAST(loans.repaid) / MAX(payments.missed)>,
#  <Feature: LAST(loans.repaid) / MAX(payments.payment_amount)>,
#  <Feature: LAST(loans.repaid) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(loans.repaid) / MEAN(loans.rate)>,
#  <Feature: LAST(loans.repaid) / MEAN(loans.repaid)>,
#  <Feature: LAST(loans.repaid) / MEAN(payments.missed)>,
#  <Feature: LAST(loans.repaid) / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.repaid) / credit_score>,
#  <Feature: LAST(loans.repaid) / income>,
#  <Feature: LAST(payments.missed) / DIFF(credit_score)>,
#  <Feature: LAST(payments.missed) / DIFF(income)>,
#  <Feature: LAST(payments.missed) / LAST(loans.loan_amount)>,
#  <Feature: LAST(payments.missed) / LAST(loans.rate)>,
#  <Feature: LAST(payments.missed) / LAST(loans.repaid)>,
#  <Feature: LAST(payments.missed) / LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.missed) / MAX(loans.loan_amount)>,
#  <Feature: LAST(payments.missed) / MAX(loans.rate)>,
#  <Feature: LAST(payments.missed) / MAX(loans.repaid)>,
#  <Feature: LAST(payments.missed) / MAX(payments.missed)>,
#  <Feature: LAST(payments.missed) / MAX(payments.payment_amount)>,
#  <Feature: LAST(payments.missed) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(payments.missed) / MEAN(loans.rate)>,
#  <Feature: LAST(payments.missed) / MEAN(loans.repaid)>,
#  <Feature: LAST(payments.missed) / MEAN(payments.missed)>,
#  <Feature: LAST(payments.missed) / MEAN(payments.payment_amount)>,
#  <Feature: LAST(payments.missed) / credit_score>,
#  <Feature: LAST(payments.missed) / income>,
#  <Feature: LAST(payments.payment_amount) / DIFF(credit_score)>,
#  <Feature: LAST(payments.payment_amount) / DIFF(income)>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.repaid)>,
#  <Feature: LAST(payments.payment_amount) / LAST(payments.missed)>,
#  <Feature: LAST(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: LAST(payments.payment_amount) / MAX(loans.repaid)>,
#  <Feature: LAST(payments.payment_amount) / MAX(payments.missed)>,
#  <Feature: LAST(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.repaid)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(payments.missed)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / credit_score>,
#  <Feature: LAST(payments.payment_amount) / income>,
#  <Feature: MAX(loans.loan_amount) / DIFF(credit_score)>,
#  <Feature: MAX(loans.loan_amount) / DIFF(income)>,
#  <Feature: MAX(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / LAST(loans.repaid)>,
#  <Feature: MAX(loans.loan_amount) / LAST(payments.missed)>,
#  <Feature: MAX(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / MAX(loans.repaid)>,
#  <Feature: MAX(loans.loan_amount) / MAX(payments.missed)>,
#  <Feature: MAX(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(loans.repaid)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(payments.missed)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / credit_score>,
#  <Feature: MAX(loans.loan_amount) / income>,
#  <Feature: MAX(loans.rate) / DIFF(credit_score)>,
#  <Feature: MAX(loans.rate) / DIFF(income)>,
#  <Feature: MAX(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / LAST(loans.rate)>,
#  <Feature: MAX(loans.rate) / LAST(loans.repaid)>,
#  <Feature: MAX(loans.rate) / LAST(payments.missed)>,
#  <Feature: MAX(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / MAX(loans.repaid)>,
#  <Feature: MAX(loans.rate) / MAX(payments.missed)>,
#  <Feature: MAX(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.repaid)>,
#  <Feature: MAX(loans.rate) / MEAN(payments.missed)>,
#  <Feature: MAX(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / credit_score>,
#  <Feature: MAX(loans.rate) / income>,
#  <Feature: MAX(loans.repaid) / DIFF(credit_score)>,
#  <Feature: MAX(loans.repaid) / DIFF(income)>,
#  <Feature: MAX(loans.repaid) / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.repaid) / LAST(loans.rate)>,
#  <Feature: MAX(loans.repaid) / LAST(loans.repaid)>,
#  <Feature: MAX(loans.repaid) / LAST(payments.missed)>,
#  <Feature: MAX(loans.repaid) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.repaid) / MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.repaid) / MAX(loans.rate)>,
#  <Feature: MAX(loans.repaid) / MAX(payments.missed)>,
#  <Feature: MAX(loans.repaid) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.repaid) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(loans.repaid) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.repaid) / MEAN(loans.repaid)>,
#  <Feature: MAX(loans.repaid) / MEAN(payments.missed)>,
#  <Feature: MAX(loans.repaid) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(loans.repaid) / credit_score>,
#  <Feature: MAX(loans.repaid) / income>,
#  <Feature: MAX(payments.missed) / DIFF(credit_score)>,
#  <Feature: MAX(payments.missed) / DIFF(income)>,
#  <Feature: MAX(payments.missed) / LAST(loans.loan_amount)>,
#  <Feature: MAX(payments.missed) / LAST(loans.rate)>,
#  <Feature: MAX(payments.missed) / LAST(loans.repaid)>,
#  <Feature: MAX(payments.missed) / LAST(payments.missed)>,
#  <Feature: MAX(payments.missed) / LAST(payments.payment_amount)>,
#  <Feature: MAX(payments.missed) / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.missed) / MAX(loans.rate)>,
#  <Feature: MAX(payments.missed) / MAX(loans.repaid)>,
#  <Feature: MAX(payments.missed) / MAX(payments.payment_amount)>,
#  <Feature: MAX(payments.missed) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(payments.missed) / MEAN(loans.rate)>,
#  <Feature: MAX(payments.missed) / MEAN(loans.repaid)>,
#  <Feature: MAX(payments.missed) / MEAN(payments.missed)>,
#  <Feature: MAX(payments.missed) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(payments.missed) / credit_score>,
#  <Feature: MAX(payments.missed) / income>,
#  <Feature: MAX(payments.payment_amount) / DIFF(credit_score)>,
#  <Feature: MAX(payments.payment_amount) / DIFF(income)>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.repaid)>,
#  <Feature: MAX(payments.payment_amount) / LAST(payments.missed)>,
#  <Feature: MAX(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / MAX(loans.repaid)>,
#  <Feature: MAX(payments.payment_amount) / MAX(payments.missed)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.repaid)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(payments.missed)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / credit_score>,
#  <Feature: MAX(payments.payment_amount) / income>,
#  <Feature: MEAN(loans.loan_amount) / DIFF(credit_score)>,
#  <Feature: MEAN(loans.loan_amount) / DIFF(income)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(loans.repaid)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(payments.missed)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.repaid)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(payments.missed)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(loans.repaid)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(payments.missed)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / credit_score>,
#  <Feature: MEAN(loans.loan_amount) / income>,
#  <Feature: MEAN(loans.rate) / DIFF(credit_score)>,
#  <Feature: MEAN(loans.rate) / DIFF(income)>,
#  <Feature: MEAN(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / LAST(loans.rate)>,
#  <Feature: MEAN(loans.rate) / LAST(loans.repaid)>,
#  <Feature: MEAN(loans.rate) / LAST(payments.missed)>,
#  <Feature: MEAN(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.rate) / MAX(loans.repaid)>,
#  <Feature: MEAN(loans.rate) / MAX(payments.missed)>,
#  <Feature: MEAN(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MEAN(loans.repaid)>,
#  <Feature: MEAN(loans.rate) / MEAN(payments.missed)>,
#  <Feature: MEAN(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / credit_score>,
#  <Feature: MEAN(loans.rate) / income>,
#  <Feature: MEAN(loans.repaid) / DIFF(credit_score)>,
#  <Feature: MEAN(loans.repaid) / DIFF(income)>,
#  <Feature: MEAN(loans.repaid) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.repaid) / LAST(loans.rate)>,
#  <Feature: MEAN(loans.repaid) / LAST(loans.repaid)>,
#  <Feature: MEAN(loans.repaid) / LAST(payments.missed)>,
#  <Feature: MEAN(loans.repaid) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(loans.repaid) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.repaid) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.repaid) / MAX(loans.repaid)>,
#  <Feature: MEAN(loans.repaid) / MAX(payments.missed)>,
#  <Feature: MEAN(loans.repaid) / MAX(payments.payment_amount)>,
#  <Feature: MEAN(loans.repaid) / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.repaid) / MEAN(loans.rate)>,
#  <Feature: MEAN(loans.repaid) / MEAN(payments.missed)>,
#  <Feature: MEAN(loans.repaid) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.repaid) / credit_score>,
#  <Feature: MEAN(loans.repaid) / income>,
#  <Feature: MEAN(payments.missed) / DIFF(credit_score)>,
#  <Feature: MEAN(payments.missed) / DIFF(income)>,
#  <Feature: MEAN(payments.missed) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(payments.missed) / LAST(loans.rate)>,
#  <Feature: MEAN(payments.missed) / LAST(loans.repaid)>,
#  <Feature: MEAN(payments.missed) / LAST(payments.missed)>,
#  <Feature: MEAN(payments.missed) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(payments.missed) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(payments.missed) / MAX(loans.rate)>,
#  <Feature: MEAN(payments.missed) / MAX(loans.repaid)>,
#  <Feature: MEAN(payments.missed) / MAX(payments.missed)>,
#  <Feature: MEAN(payments.missed) / MAX(payments.payment_amount)>,
#  <Feature: MEAN(payments.missed) / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(payments.missed) / MEAN(loans.rate)>,
#  <Feature: MEAN(payments.missed) / MEAN(loans.repaid)>,
#  <Feature: MEAN(payments.missed) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(payments.missed) / credit_score>,
#  <Feature: MEAN(payments.missed) / income>,
#  <Feature: MEAN(payments.payment_amount) / DIFF(credit_score)>,
#  <Feature: MEAN(payments.payment_amount) / DIFF(income)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(loans.repaid)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(payments.missed)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(loans.repaid)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(payments.missed)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(loans.repaid)>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(payments.missed)>,
#  <Feature: MEAN(payments.payment_amount) / credit_score>,
#  <Feature: MEAN(payments.payment_amount) / income>,
#  <Feature: credit_score / DIFF(credit_score)>,
#  <Feature: credit_score / DIFF(income)>,
#  <Feature: credit_score / LAST(loans.loan_amount)>,
#  <Feature: credit_score / LAST(loans.rate)>,
#  <Feature: credit_score / LAST(loans.repaid)>,
#  <Feature: credit_score / LAST(payments.missed)>,
#  <Feature: credit_score / LAST(payments.payment_amount)>,
#  <Feature: credit_score / MAX(loans.loan_amount)>,
#  <Feature: credit_score / MAX(loans.rate)>,
#  <Feature: credit_score / MAX(loans.repaid)>,
#  <Feature: credit_score / MAX(payments.missed)>,
#  <Feature: credit_score / MAX(payments.payment_amount)>,
#  <Feature: credit_score / MEAN(loans.loan_amount)>,
#  <Feature: credit_score / MEAN(loans.rate)>,
#  <Feature: credit_score / MEAN(loans.repaid)>,
#  <Feature: credit_score / MEAN(payments.missed)>,
#  <Feature: credit_score / MEAN(payments.payment_amount)>,
#  <Feature: income / DIFF(credit_score)>,
#  <Feature: income / DIFF(income)>,
#  <Feature: income / LAST(loans.loan_amount)>,
#  <Feature: income / LAST(loans.rate)>,
#  <Feature: income / LAST(loans.repaid)>,
#  <Feature: income / LAST(payments.missed)>,
#  <Feature: income / LAST(payments.payment_amount)>,
#  <Feature: income / MAX(loans.loan_amount)>,
#  <Feature: income / MAX(loans.rate)>,
#  <Feature: income / MAX(loans.repaid)>,
#  <Feature: income / MAX(payments.missed)>,
#  <Feature: income / MAX(payments.payment_amount)>,
#  <Feature: income / MEAN(loans.loan_amount)>,
#  <Feature: income / MEAN(loans.rate)>,
#  <Feature: income / MEAN(loans.repaid)>,
#  <Feature: income / MEAN(payments.missed)>,
#  <Feature: income / MEAN(payments.payment_amount)>,
#  <Feature: YEAR(LAST(loans.loan_end))>,
#  <Feature: YEAR(LAST(loans.loan_start))>,
#  <Feature: YEAR(LAST(payments.payment_date))>]

# %%
pd.DataFrame(features['MEAN(loans.loan_amount)'].head(10))
# Out:
#            MEAN(loans.loan_amount)
# client_id
# 2447                  11291.666667
# 2963                   8586.000000
# 3294                  12812.500000
# 3895                   5542.285714
# 3469                   8128.777778
# 2265                   7562.055556
# 3432                           NaN
# 4829                   8279.722222
# 3567                   7507.250000
# 2242                   8821.545455

# %%
loans.loc[loans['client_id'] == 2447]
# Out:
#       client_id loan_type  loan_amount  repaid  loan_id loan_start   loan_end  \
# 1365       2447      cash        10116       0    10285 2014-12-03 2016-07-13
# 1366       2447      home        14986       1    11983 2005-04-05 2007-09-01
# 1367       2447      cash         8773       1    10222 2001-01-08 2003-01-30
#
#        rate
# 1365   2.63
# 1366  10.16
# 1367   3.66

# %%
payments.loc[payments['loan_id'] == 10285]
# Out:
#        payment_id  loan_id  payment_amount payment_date  missed
# 16131       16131    10285            1206   2015-01-14       1
# 16132       16132    10285            1793   2015-02-04       0
# 16133       16133    10285            1675   2015-03-10       1
# 16134       16134    10285            1716   2015-04-26       1
# 16135       16135    10285            1206   2015-05-28       1
# 31559       31559    10285             778   2014-06-10       1
# 31560       31560    10285            1265   2014-06-29       1
# 31561       31561    10285             899   2014-08-16       1
# 31562       31562    10285            1149   2014-09-22       0
# 31563       31563    10285             798   2014-10-20       0
# 31564       31564    10285            1208   2014-12-06       1

# %%
pd.DataFrame(features['LAST(loans.MEAN(payments.payment_amount))'].head(10))
# Out:
#            LAST(loans.MEAN(payments.payment_amount))
# client_id
# 2447                                     1244.818182
# 2963                                     1165.909091
# 3294                                     2377.000000
# 3895                                     1711.666667
# 3469                                      445.142857
# 2265                                      969.821429
# 3432                                             NaN
# 4829                                     1016.550000
# 3567                                     1157.407407
# 2242                                     1657.833333
